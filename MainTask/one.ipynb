# 48847  (1874, 518)  (1389, 283)  2024-07-25 19:40:00.363760
#
#                         Exit_Time
# 48838  2024-07-25 19:40:23.372458
# 48839  2024-07-25 19:40:23.372564
# 48840  2024-07-25 19:40:24.055978
# 48841  2024-07-25 19:40:24.056083
# 48842  2024-07-25 19:40:24.056190
# 48843  2024-07-25 19:40:24.056295
# 48844  2024-07-25 19:40:24.631744
# ...

# %%
df.columns
# Out:
# Index(['Entry_Point', 'Exit_Point', 'Entry_Time', 'Exit_Time'], dtype='object')

# %%
df['Entry_Time'].dtype
# Out:
# dtype('O')

# %%
#Convert the Entry_Time column to datetime
df['Entry_Time'] = pd.to_datetime(df['Entry_Time'])
df['Entry_Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Hour and minute of Entry time column
df['Entry_Hour'] = df['Entry_Time'].dt.hour
df['Entry_Minute'] = df['Entry_Time'].dt.minute

# %%
df.head()
# Out:
#    Entry_Point   Exit_Point                 Entry_Time  \
# 0  (1176, 471)   (360, 572) 2024-07-25 18:43:00.126934
# 1  (1176, 471)   (714, 517) 2024-07-25 18:43:00.126934
# 2  (1176, 471)  (1170, 469) 2024-07-25 18:43:00.126934
# 3  (1176, 471)   (353, 574) 2024-07-25 18:43:00.126934
# 4  (1176, 471)   (712, 518) 2024-07-25 18:43:00.126934
#
#                     Exit_Time  Entry_Hour  Entry_Minute
# 0  2024-07-25 18:43:01.350517          18            43
# 1  2024-07-25 18:43:01.350605          18            43
# 2  2024-07-25 18:43:01.350672          18            43
# 3  2024-07-25 18:43:01.955511          18            43
# 4  2024-07-25 18:43:01.955585          18            43

# %%
df.tail()
# Out:
#        Entry_Point   Exit_Point                 Entry_Time  \
# 48843  (1874, 518)  (1395, 287) 2024-07-25 19:40:00.363760
# 48844  (1874, 518)   (760, 250) 2024-07-25 19:40:00.363760
# 48845  (1874, 518)  (1217, 210) 2024-07-25 19:40:00.363760
# 48846  (1874, 518)   (786, 319) 2024-07-25 19:40:00.363760
# 48847  (1874, 518)  (1389, 283) 2024-07-25 19:40:00.363760
#
#                         Exit_Time  Entry_Hour  Entry_Minute
# 48843  2024-07-25 19:40:24.056295          19            40
# 48844  2024-07-25 19:40:24.631744          19            40
# 48845  2024-07-25 19:40:24.631838          19            40
# 48846  2024-07-25 19:40:24.631931          19            40
# 48847  2024-07-25 19:40:24.632025          19            40

# %%
df['Entry_Minute'].nunique()
# Out:
# 58

# %%
# Add Exit hour and exit minute columns
df['Exit_Time'] = pd.to_datetime(df['Exit_Time'])
df['Exit_Hour'] = df['Exit_Time'].dt.hour
df['Exit_Minute'] = df['Exit_Time'].dt.minute

# %%
df.head()
# Out:
#    Entry_Point   Exit_Point                 Entry_Time  \
# 0  (1176, 471)   (360, 572) 2024-07-25 18:43:00.126934
# 1  (1176, 471)   (714, 517) 2024-07-25 18:43:00.126934
# 2  (1176, 471)  (1170, 469) 2024-07-25 18:43:00.126934
# 3  (1176, 471)   (353, 574) 2024-07-25 18:43:00.126934
# 4  (1176, 471)   (712, 518) 2024-07-25 18:43:00.126934
#
#                    Exit_Time  Entry_Hour  Entry_Minute  Exit_Hour  Exit_Minute
# 0 2024-07-25 18:43:01.350517          18            43         18           43
# 1 2024-07-25 18:43:01.350605          18            43         18           43
# 2 2024-07-25 18:43:01.350672          18            43         18           43
# 3 2024-07-25 18:43:01.955511          18            43         18           43
# 4 2024-07-25 18:43:01.955585          18            43         18           43

# %%
# make a bar plot for number of vehichles in each hour
plt.figure(figsize=(10,6))
sns.countplot(x='Entry_Hour', data=df)
plt.title('Number of vehicles in each hour')
plt.show()

# %%
# Plot the df["Entry Minute"] column 
plt.figure(figsize=(18,6))
sns.countplot(x='Entry_Minute', data=df)
plt.title('Number of vehicles in each minute')
plt.show()

# %%
# Plot exit minute
plt.figure(figsize=(18,6))
sns.countplot(x='Exit_Minute', data=df)
plt.title('Number of vehicles in each minute')
plt.show()

# %%
# PLot the difference of number of vehichles entered and exited in each minute
plt.figure(figsize=(18,6))
sns.countplot(x='Entry_Minute', data=df, color='blue', alpha=0.5)
sns.countplot(x='Exit_Minute', data=df, color='red', alpha=0.5)
plt.title('Number of vehicles in each minute')
plt.show()

# %%
# Make a column name interval and which has value equal to the difference of number of vehichles entered and exited in each minute
df['Interval'] = df['Entry_Minute'] - df['Exit_Minute']
df.head()
# Out:
#    Entry_Point   Exit_Point                 Entry_Time  \
# 0  (1176, 471)   (360, 572) 2024-07-25 18:43:00.126934
# 1  (1176, 471)   (714, 517) 2024-07-25 18:43:00.126934
# 2  (1176, 471)  (1170, 469) 2024-07-25 18:43:00.126934
# 3  (1176, 471)   (353, 574) 2024-07-25 18:43:00.126934
# 4  (1176, 471)   (712, 518) 2024-07-25 18:43:00.126934
#
#                    Exit_Time  Entry_Hour  Entry_Minute  Exit_Hour  \
# 0 2024-07-25 18:43:01.350517          18            43         18
# 1 2024-07-25 18:43:01.350605          18            43         18
# 2 2024-07-25 18:43:01.350672          18            43         18
# 3 2024-07-25 18:43:01.955511          18            43         18
# 4 2024-07-25 18:43:01.955585          18            43         18
#
#    Exit_Minute  Interval
# 0           43         0
# 1           43         0
# 2           43         0
# 3           43         0
# 4           43         0

# %%
# Plot the interval column
plt.figure(figsize=(18,6))
sns.countplot(x='Interval', data=df)
plt.title('Number of vehicles in each interval')
plt.show()

# %%
df.head()
# Out:
#    Entry_Point   Exit_Point                 Entry_Time  \
# 0  (1176, 471)   (360, 572) 2024-07-25 18:43:00.126934
# 1  (1176, 471)   (714, 517) 2024-07-25 18:43:00.126934
# 2  (1176, 471)  (1170, 469) 2024-07-25 18:43:00.126934
# 3  (1176, 471)   (353, 574) 2024-07-25 18:43:00.126934
# 4  (1176, 471)   (712, 518) 2024-07-25 18:43:00.126934
#
#                    Exit_Time  Entry_Hour  Entry_Minute  Exit_Hour  \
# 0 2024-07-25 18:43:01.350517          18            43         18
# 1 2024-07-25 18:43:01.350605          18            43         18
# 2 2024-07-25 18:43:01.350672          18            43         18
# 3 2024-07-25 18:43:01.955511          18            43         18
# 4 2024-07-25 18:43:01.955585          18            43         18
#
#    Exit_Minute  Interval
# 0           43         0
# 1           43         0
# 2           43         0
# 3           43         0
# 4           43         0

# %%
# Remove Date from the Entry_time and Exit_time columns
df['Entry_Time'] = df['Entry_Time'].dt.time
df['Exit_Time'] = df['Exit_Time'].dt.time
df.head()
# Out:
#    Entry_Point   Exit_Point       Entry_Time        Exit_Time  Entry_Hour  \
# 0  (1176, 471)   (360, 572)  18:43:00.126934  18:43:01.350517          18
# 1  (1176, 471)   (714, 517)  18:43:00.126934  18:43:01.350605          18
# 2  (1176, 471)  (1170, 469)  18:43:00.126934  18:43:01.350672          18
# 3  (1176, 471)   (353, 574)  18:43:00.126934  18:43:01.955511          18
# 4  (1176, 471)   (712, 518)  18:43:00.126934  18:43:01.955585          18
#
#    Entry_Minute  Exit_Hour  Exit_Minute  Interval
# 0            43         18           43         0
# 1            43         18           43         0
# 2            43         18           43         0
# 3            43         18           43         0
# 4            43         18           43         0

# %%
# remove seconds from the Entry_time and Exit_time columns

# %%
# Add 2 minute interval column according to entry_minute for ex, all vecihles entered between 0-2 minutes will have interval 0-2
# all vechicles entered between 2-4 minutes will have interval 2-4 and similarly for all other intervals

# in our case intervals should be like 18:43 - 18:45, 18:45 - 18:47, 18:47 - 18:49 and so on
# for this we can use pd.cut() function

df['Interval'] = pd.cut(df['Entry_Minute'], bins=range(0,61,2), right=False)
df.head()

# add another column for the exit_minute interval
df['Exit_Interval'] = pd.cut(df['Exit_Minute'], bins=range(0,61,2), right=False)
df.head()
# Out:
#    Entry_Point   Exit_Point       Entry_Time        Exit_Time  Entry_Hour  \
# 0  (1176, 471)   (360, 572)  18:43:00.126934  18:43:01.350517          18
# 1  (1176, 471)   (714, 517)  18:43:00.126934  18:43:01.350605          18
# 2  (1176, 471)  (1170, 469)  18:43:00.126934  18:43:01.350672          18
# 3  (1176, 471)   (353, 574)  18:43:00.126934  18:43:01.955511          18
# 4  (1176, 471)   (712, 518)  18:43:00.126934  18:43:01.955585          18
#
#    Entry_Minute  Exit_Hour  Exit_Minute  Interval Exit_Interval
# 0            43         18           43  [42, 44)      [42, 44)
# 1            43         18           43  [42, 44)      [42, 44)
# 2            43         18           43  [42, 44)      [42, 44)
# 3            43         18           43  [42, 44)      [42, 44)
# 4            43         18           43  [42, 44)      [42, 44)

# %%
# Plot the interval column
plt.figure(figsize=(18,6))

#plot exit interval and entry interval
sns.countplot(x='Interval', data=df, color='blue', alpha=0.5)
sns.countplot(x='Exit_Interval', data=df, color='red', alpha=0.5)
plt.title('Number of vehicles in each interval')

# decrease the font size of xticks
plt.xticks(fontsize=8)
plt.show()

# %%
# Do the seasonal plot for number of vehicles in each interval
plt.figure(figsize=(18,6))
df['Interval'].value_counts().sort_index().plot(style='.-')
df['Exit_Interval'].value_counts().sort_index().plot(style='.-')
plt.title('Number of vehicles in each interval')
plt.show()

# %%
df.head(1)
# Out:
#    Entry_Point  Exit_Point       Entry_Time        Exit_Time  Entry_Hour  \
# 0  (1176, 471)  (360, 572)  18:43:00.126934  18:43:01.350517          18
#
#    Entry_Minute  Exit_Hour  Exit_Minute  Interval Exit_Interval
# 0            43         18           43  [42, 44)      [42, 44)

# %%
# Decompose the above plot into trend, seasonality and residual
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df['Interval'].value_counts().sort_index(), model='additive', period=2)

# %%
# Plot trend seasonality and residual in one plot
plt.figure(figsize=(18,6))
result.trend.plot()
result.seasonal.plot()
result.resid.plot()

# Label the plot
plt.title('Trend, Seasonality and Residual')
plt.legend(['Trend', 'Seasonality', 'Residual'])

plt.show()

# %%
df.head(2)
# Out:
#    Entry_Point  Exit_Point       Entry_Time        Exit_Time  Entry_Hour  \
# 0  (1176, 471)  (360, 572)  18:43:00.126934  18:43:01.350517          18
# 1  (1176, 471)  (714, 517)  18:43:00.126934  18:43:01.350605          18
#
#    Entry_Minute  Exit_Hour  Exit_Minute  Interval Exit_Interval
# 0            43         18           43  [42, 44)      [42, 44)
# 1            43         18           43  [42, 44)      [42, 44)

# %% [markdown]
# # Naive Forecast Model

# %%
interval_counts.index = range(len(interval_counts))

# Convert the interval counts to a TimeSeries
series = TimeSeries.from_series(interval_counts)

#1. Naive Forecast
from darts.models import NaiveSeasonal
naivemodel = NaiveSeasonal(K=5) # Previous K steps will be repeated

# forecase next 15 steps and plot the forecast
naivemodel.fit(series)
naive_forecast = naivemodel.predict(15)

# Convert the forecasted TimeSeries to Pandas Series
forecast_series = naive_forecast.pd_series()

# Concatenate the original and forecasted series
combined_series = pd.concat([interval_counts, forecast_series])

# Plot the combined series
plt.figure(figsize=(12, 5))
combined_series.plot(label='Forecasted', color='orange')
interval_counts.plot(label='Original', color='blue')
plt.legend()
plt.title('Vehicle Count Forecast')
plt.xlabel('Interval')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Exponential Smoothing (ETS)

# %%
from darts.models import ExponentialSmoothing
from darts.utils.utils import ModelMode, SeasonalityMode

# Fit the Simple Exponential Smoothing model
ses_model = ExponentialSmoothing(trend=ModelMode.NONE, seasonal=SeasonalityMode.NONE)
ses_model.fit(series)
ses_forecast = ses_model.predict(15)

# Convert the forecast to Pandas Series and plot
ses_forecast_series = ses_forecast.pd_series()
combined_ses_series = pd.concat([interval_counts, ses_forecast_series])

plt.figure(figsize=(10, 6))
combined_ses_series.plot(label='SES Forecasted', color='orange')
interval_counts.plot(label='Original', color='blue')
plt.legend()
plt.title('Simple Exponential Smoothing Forecast')
plt.xlabel('Interval')
plt.ylabel('Count')
plt.show()

# %%
# Holt's Exponential Smoothing Model
holtModel = ExponentialSmoothing(trend=ModelMode.ADDITIVE, seasonal=SeasonalityMode.ADDITIVE)
holtModel.fit(series)

holt_forecast = holtModel.predict(15)

holt_forecast_series = holt_forecast.pd_series()
combined_holt_series = pd.concat([interval_counts, holt_forecast_series])

plt.figure(figsize=(10, 6))
combined_holt_series.plot(label='Holt Forecasted', color='orange')
interval_counts.plot(label='Original', color='blue')
plt.legend()
plt.title('Holt Forecast')
plt.xlabel('Interval')
plt.ylabel('Count')
plt.show()
